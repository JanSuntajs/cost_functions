# %%
# %matplotlib notebook
import numpy as np
from glob import glob
from scipy.optimize import minimize, differential_evolution
from matplotlib import pyplot as plt

from costfun import *

# %%
files = './data/*'
files = np.sort(glob(files))

vals = np.array([np.loadtxt(file) for file in files])


x = np.array([val[:,0] for val in vals])
y = np.array([val[:,1] for val in vals])

x, y = pad_vals(x,y)

sizelist = np.array([12, 14, 16, 18, 20])

# %%
# %%time
popsize0 = 100
maxiter0 = 1000
#x0 = np.zeros(len(sizelist) + 1, dtype=np.float64)
x0 = np.zeros(6, dtype = np.float64)
bounds = [(0., 5) for el in x0]
bounds[-1] = (0.1, 4)
# x0[0] = 0.54
# x0[1] = 0.10
# x0[-1] = 1.90
optRes = differential_evolution(minimization_fun,
                                bounds,
                                args=(x, y, sizelist, 'free', 'kt',
                                      False),
                                popsize=popsize0,
                                maxiter=maxiter0, workers=2)

print(optRes)
params = optRes.x
# Out:
# /home/jan/Dropbox/Sync_WD_MyCloud/Faks/3._stopnja/Koda/cost_functions/rescale_functions.py:53: RuntimeWarning: overflow encountered in exp
#   x) * sizelist[:, np.newaxis] / np.exp(a / np.abs(x) ** 0.5)
# /home/jan/Dropbox/Sync_WD_MyCloud/Faks/3._stopnja/Koda/cost_functions/rescale_functions.py:53: RuntimeWarning: overflow encountered in exp
#   x) * sizelist[:, np.newaxis] / np.exp(a / np.abs(x) ** 0.5)
#      fun: 0.47298384258082504
#  message: 'Optimization terminated successfully.'
#     nfev: 142807
#      nit: 237
#  success: True
#        x: array([3.54723595, 3.87764235, 4.22168511, 4.61223901, 4.92842464,
#        2.70822747])
# CPU times: user 11.4 s, sys: 346 ms, total: 11.8 s
# Wall time: 22.4 s

# %%
results_folder = './results/crit_point_scaling_free/rescale_kt/r_*'
filenames = np.sort(glob(results_folder))

data = np.array([np.load(filename, allow_pickle=True)['params'] for filename in filenames])

# %%
costfun_params = np.array([np.load(filename, allow_pickle=True)['params'] for filename in filenames])

# %%
params_opt = np.mean(costfun_params, axis=0)
params_opt
# Out:
# array([2.18302876, 2.64605262, 3.08401013, 3.4823638 , 3.92268213,
#        4.44904902])

# %%
#params_ = np.zeros(6, dtype=np.float64)
#params_[:5] = 0.05 + 0.1 * sizelist
#params_[-1] = 1.96

xopt, yopt, cost = minimization_fun(params_opt, x, y, sizelist,'free','kt','sub',True)

# %%
fig = plt.figure()

plt.plot(xopt, yopt, 'o', ms=1)
plt.show()
print(cost)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.8569869977072384

# %%
x
# Out:
# array([[1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#         3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#         6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#         9.25, 9.5 ],
#        [1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#         3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#         6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#         9.25, 9.5 ],
#        [1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#         3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#         6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#         9.25, 9.5 ],
#        [1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#         3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#         6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
# ...
